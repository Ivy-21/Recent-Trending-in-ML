# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls

# %%
cd drive/MyDrive/RTML/Midsem_prep/data
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/RTML/Midsem_prep/data'
# /root

# %%
cd /content/drive/MyDrive/RTML/Midsem_prep/data
# Out:
# /content/drive/MyDrive/RTML/Midsem_prep/data

# %%
ls
# Out:
# cookies.txt              index.html    leftImg8bit_trainvaltest.zip
# gtFine/                  index.html.1  license.txt
# gtFine_trainvaltest.zip  leftImg8bit/  README

# %%
#cd ..
# Out:
# /content/drive/MyDrive/RTML/Midsem_prep

# %% [markdown]
# # CityScape data download

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=aungzarlin&password=G0e12#e0g&submit=Login' https://www.cityscapes-dataset.com/login/
# Out:
# --2022-03-03 10:37:54--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2022-03-03 10:37:55--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1            [ <=>                ]  47.44K  --.-KB/s    in 0.1s
#
# 2022-03-03 10:37:55 (393 KB/s) - ‘index.html.1’ saved [48580]

# %%
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Out:
# --2022-03-03 10:37:59--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252567705 (241M) [application/octet-stream]
# Saving to: ‘gtFine_trainvaltest.zip’
#
# gtFine_trainvaltest 100%[===================>] 240.87M  24.9MB/s    in 11s
#
# 2022-03-03 10:38:11 (21.2 MB/s) - ‘gtFine_trainvaltest.zip’ saved [252567705/252567705]

# %%
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2022-03-03 10:38:31--  https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11592327197 (11G) [application/octet-stream]
# Saving to: ‘leftImg8bit_trainvaltest.zip’
#
# leftImg8bit_trainva 100%[===================>]  10.80G  22.2MB/s    in 7m 24s
#
# 2022-03-03 10:45:55 (24.9 MB/s) - ‘leftImg8bit_trainvaltest.zip’ saved [11592327197/11592327197]

# %%
ls
# Out:
#  AlexNet.ipynb               GAN.ipynb                      List.gdoc
#  cityscape_mask_rcnn.ipynb   GoogLeNet.ipynb                Masked-R-CNN.ipynb
#  Collection.ipynb            index.html                    'Resnet&SEnet.ipynb'
#  cookies.txt                 index.html.1                   YOLO.ipynb
#  data/                       leftImg8bit_trainvaltest.zip

# %%
cd data/
# Out:
# /content/drive/MyDrive/RTML/Midsem_prep/data

# %%
# !unzip gtFine_trainvaltest.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: gtFine/test/berlin/berlin_000117_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000114_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000434_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000420_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000483_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000420_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000254_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000490_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000448_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000099_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000068_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000288_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000409_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000432_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000412_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000114_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000362_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000375_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000190_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000227_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000422_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000450_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000132_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000396_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000268_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000153_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000202_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000309_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000174_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000016_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000483_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000365_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000018_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000400_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000129_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000113_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000419_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000181_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000000_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000276_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000322_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000137_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000160_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000095_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000526_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000082_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000514_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000368_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000187_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000290_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000156_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000144_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000186_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000047_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000159_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000335_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000516_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000128_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000303_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000472_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000481_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000467_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000197_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000076_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000183_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000528_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000185_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000319_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000330_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000520_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000091_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000370_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000255_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000275_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000203_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000395_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000431_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000393_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000504_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000406_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000491_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000028_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000293_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000518_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000195_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000156_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000251_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000246_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000196_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000441_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000236_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000034_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000184_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000070_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000465_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000506_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000259_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000184_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000310_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000497_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000196_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000216_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000380_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000329_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000179_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000011_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000522_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000118_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000470_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000117_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000059_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000276_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000176_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000064_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000195_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000106_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000080_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000226_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000168_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000339_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000163_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000238_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000191_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000096_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000096_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000039_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000218_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000155_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000264_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000363_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000355_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000522_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000267_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000178_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000495_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000485_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000205_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000415_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000165_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000443_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000472_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000079_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000075_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000327_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000250_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000031_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000380_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000029_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000137_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000053_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000435_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000216_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000161_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000171_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000460_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000186_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000269_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000465_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000323_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000262_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000305_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000403_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000149_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000140_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000297_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000105_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000306_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000386_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000172_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000406_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000423_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000001_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000124_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000090_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000280_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000110_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000456_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000195_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000066_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000034_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000208_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000111_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000002_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000425_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000093_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000019_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000517_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000142_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000369_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000017_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000204_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000112_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000333_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000294_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000062_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000085_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000036_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000172_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000304_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000097_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000166_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000344_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000219_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000084_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000309_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000475_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000459_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000314_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000427_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000262_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000247_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000143_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000030_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000293_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000458_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000430_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000532_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000340_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000467_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000118_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000383_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000426_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000135_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000390_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000433_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000259_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000490_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000193_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000097_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000197_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000524_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000508_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000268_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000383_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000043_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000492_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000336_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000068_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000435_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000538_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000371_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000237_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000233_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000025_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000507_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000058_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000536_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000426_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000178_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000247_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000441_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000390_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000075_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000460_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000193_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000482_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000411_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000302_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000060_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000391_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000482_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000310_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000315_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000366_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000300_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000524_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000154_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000266_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000096_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000183_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000164_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000278_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000067_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000048_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000349_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000409_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000369_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000477_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000316_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000051_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000069_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000335_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000542_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000328_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000053_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000286_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000080_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000528_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000308_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000002_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000408_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000040_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000329_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000132_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000211_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000412_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000043_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000361_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000044_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000181_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000503_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000086_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000133_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000206_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000097_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000128_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000433_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000447_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000371_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000123_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000048_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000073_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000186_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000182_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000480_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000040_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000493_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000366_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000265_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000209_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000236_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000427_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000442_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000212_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000174_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000260_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000111_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000097_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000291_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000027_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000061_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000444_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000455_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000045_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000099_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000408_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000015_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000286_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000473_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000401_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000399_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000122_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000252_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000529_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000036_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000529_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000302_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000275_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000372_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000124_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000293_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000197_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000119_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000244_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000108_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000363_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000507_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000503_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000485_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000460_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000065_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000440_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000102_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000488_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000515_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000291_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000492_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000286_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000228_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000072_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000196_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000126_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000275_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000176_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000177_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000470_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000278_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000208_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000349_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000463_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000077_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000308_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000199_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000227_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000369_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000301_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000354_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000015_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000485_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000207_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000354_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000322_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000360_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000457_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000045_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000528_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000067_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000391_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000128_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000498_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000448_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000423_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000362_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000372_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000383_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000527_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000323_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000243_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000173_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000384_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000411_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000325_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000356_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000374_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000394_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000298_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000198_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000234_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000249_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000167_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000299_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000483_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000207_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000324_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000191_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000227_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000238_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000364_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000239_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000209_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000130_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000338_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000355_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000518_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000000_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000523_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000378_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000129_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000529_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000023_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000177_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000213_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000339_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000163_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000373_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000280_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000285_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000121_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000175_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000376_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000538_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000109_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000065_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000170_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000326_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000397_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000182_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000167_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000259_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000271_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000408_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000419_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000533_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000061_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000086_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000426_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000386_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000484_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000469_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000477_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000346_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000480_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000283_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000003_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000003_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000239_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000508_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000145_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000049_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000059_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000353_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000360_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000126_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000488_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000539_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000297_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000182_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000537_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000210_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000005_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000199_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000228_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000199_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000128_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000081_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000089_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000417_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000066_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000050_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000116_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000516_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000412_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000238_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000494_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000535_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000164_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000339_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000270_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000471_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000154_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000474_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000199_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000350_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000318_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000459_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000412_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000157_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000233_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000180_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000093_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000296_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000447_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000337_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000131_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000133_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000244_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000060_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000057_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000478_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000366_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000175_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000368_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000440_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000313_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000037_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000296_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000038_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000080_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000201_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000215_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000384_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000109_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000120_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000328_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000220_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000317_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000336_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000103_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000319_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000269_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000493_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000486_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000044_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000027_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000089_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000414_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000501_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000442_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000024_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000429_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000043_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000044_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000424_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000190_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000526_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000314_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000074_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000471_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000432_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000542_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000525_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000487_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000320_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000532_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000193_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000013_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000090_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000169_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000018_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000039_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000515_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000351_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000481_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000504_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000115_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000391_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000144_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000468_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000197_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000025_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000329_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000439_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000450_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000384_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000151_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000512_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000377_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000304_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000333_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000425_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000448_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000311_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000119_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000217_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000356_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000357_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000343_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000428_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000008_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000425_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000147_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000053_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000432_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000042_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000141_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000273_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000218_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000067_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000437_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000375_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000371_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000043_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000026_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000373_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000309_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000297_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000108_000019_gtFine_labelIds.png
#   inflating: gtFine/test/berlin/berlin_000078_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000139_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000238_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000007_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000033_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000144_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/berlin/berlin_000149_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000478_000019_gtFine_polygons.json
#   inflating: gtFine/test/berlin/berlin_000005_000019_gtFine_color.png
#   inflating: gtFine/test/berlin/berlin_000008_000019_gtFine_color.png
# ...
#   inflating: gtFine/test/munich/munich_000286_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000038_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000066_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000205_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000251_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000083_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000299_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000250_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000323_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000190_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000176_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000058_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000253_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000072_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000148_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000119_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000396_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000101_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000324_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000195_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000232_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000168_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000062_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000300_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000386_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000192_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000185_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000109_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000158_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000159_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000376_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000088_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000009_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000379_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000187_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000097_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000174_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000347_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000303_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000340_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000189_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000230_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000298_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000288_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000267_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000381_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000393_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000093_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000207_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000336_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000099_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000045_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000319_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000082_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000081_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000124_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000208_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000335_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000089_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000346_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000382_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000182_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000312_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000037_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000114_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000295_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000365_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000305_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000283_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000011_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000244_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000238_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000129_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000179_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000108_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000238_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000249_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000044_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000051_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000367_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000334_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000285_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000019_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000055_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000318_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000271_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000141_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000117_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000108_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000101_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000153_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000326_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000210_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000269_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000286_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000151_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000113_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000163_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000292_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000349_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000060_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000219_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000009_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000019_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000281_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000289_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000357_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000188_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000044_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000375_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000278_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000341_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000169_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000397_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000016_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000287_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000278_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000121_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000041_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000342_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000082_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000378_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000121_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000022_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000140_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000375_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000135_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000307_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000053_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000024_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000127_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000074_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000144_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000030_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000015_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000172_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000123_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000002_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000135_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000070_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000390_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000346_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000063_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000119_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000293_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000226_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000329_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000289_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000309_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000216_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000128_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000141_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000034_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000003_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000160_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000024_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000313_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000356_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000382_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000077_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000091_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000332_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000301_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000144_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000085_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000342_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000051_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000145_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000152_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000026_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000236_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000166_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000264_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000187_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000251_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000248_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000046_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000168_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000333_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000148_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000078_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000349_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000027_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000328_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000063_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000394_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000279_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000023_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000054_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000344_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000256_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000276_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000270_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000033_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000012_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000342_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000180_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000228_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000386_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000382_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000317_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000215_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000225_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000076_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000396_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000223_000019_gtFine_color.png
#   inflating: gtFine/test/munich/munich_000031_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000242_000019_gtFine_labelIds.png
#   inflating: gtFine/test/munich/munich_000030_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000066_000019_gtFine_instanceIds.png
#   inflating: gtFine/test/munich/munich_000220_000019_gtFine_polygons.json
#   inflating: gtFine/test/munich/munich_000150_000019_gtFine_instanceIds.png

# %%
# !unzip leftImg8bit_trainvaltest.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: leftImg8bit/train/jena/jena_000074_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000040_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000020_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000030_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000005_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000059_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000100_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000034_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000089_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000104_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000107_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000080_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000006_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000082_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000044_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000026_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000115_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000023_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000095_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000099_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000102_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000094_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000010_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000009_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000070_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000039_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000079_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000071_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000018_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000008_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000076_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000090_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000085_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000116_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000063_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000049_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000022_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000014_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000015_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000118_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000004_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000087_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000047_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000007_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000033_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000097_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000028_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000086_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000073_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000064_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000056_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000069_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000011_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000088_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000103_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000057_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000003_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000038_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000061_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000048_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000060_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000027_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000031_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000072_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000043_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000054_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000083_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000077_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000108_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000106_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000084_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000075_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000024_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000110_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000029_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000000_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000117_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000036_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000046_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000062_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000035_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000019_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000093_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000112_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000025_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000013_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000113_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000053_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000098_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000066_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/jena/jena_000041_000019_leftImg8bit.png
#    creating: leftImg8bit/train/stuttgart/
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000110_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000107_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000087_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000188_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000175_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000147_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000043_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000042_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000118_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000191_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000189_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000007_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000112_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000032_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000085_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000077_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000144_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000161_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000149_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000113_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000194_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000017_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000010_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000057_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000143_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000067_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000178_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000070_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000026_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000056_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000171_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000128_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000157_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000100_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000158_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000125_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000134_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000168_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000156_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000162_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000024_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000037_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000094_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000129_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000069_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000011_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000000_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000095_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000002_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000160_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000111_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000039_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000184_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000038_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000165_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000040_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000060_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000046_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000065_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000022_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000122_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000135_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000030_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000133_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000172_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000105_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000041_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000014_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000142_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000079_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000081_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000183_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000173_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000028_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000083_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000071_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000106_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000169_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000126_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000019_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000148_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000078_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000023_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000003_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000108_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000153_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000033_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000088_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000027_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000016_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000036_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000181_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000044_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000182_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000140_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000186_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000090_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000082_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000075_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000099_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000124_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000176_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000009_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000154_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000008_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000004_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000048_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000020_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000093_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000152_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000155_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000051_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000138_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000116_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000136_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000103_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000115_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000145_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000035_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000163_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000101_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000005_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000114_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000029_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000063_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000139_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000150_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000123_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000064_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000190_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000092_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000091_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000130_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000164_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000170_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000131_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000031_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000159_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000054_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000167_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000012_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000104_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000021_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000053_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000058_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000049_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000001_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000179_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000066_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000034_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000050_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000013_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000045_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000068_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000137_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000086_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000187_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000080_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000097_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000192_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000195_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000132_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000015_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000025_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000096_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000059_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000102_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000174_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000166_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000180_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000185_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000098_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000141_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000151_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000006_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000047_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000146_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000072_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000119_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000073_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000089_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000055_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000193_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000018_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000117_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000109_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000076_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000074_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000177_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000127_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000052_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000121_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000120_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000084_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000061_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/stuttgart/stuttgart_000062_000019_leftImg8bit.png
#    creating: leftImg8bit/train/ulm/
#  extracting: leftImg8bit/train/ulm/ulm_000019_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000063_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000066_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000042_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000037_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000001_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000091_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000004_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000050_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000034_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000092_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000090_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000054_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000045_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000079_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000038_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000088_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000032_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000020_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000071_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000033_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000027_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000068_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000002_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000084_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000003_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000013_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000094_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000000_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000026_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000061_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000069_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000065_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000077_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000009_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000017_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000021_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000076_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000012_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000074_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000022_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000055_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000072_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000093_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000018_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000028_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000075_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000044_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000043_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000062_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000059_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000052_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000082_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000053_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000006_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000087_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000024_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000081_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000025_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000007_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000070_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000080_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000057_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000085_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000011_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000064_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000005_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000046_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000067_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000060_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000040_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000010_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000073_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000023_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000031_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000089_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000039_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000016_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000058_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000047_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000048_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000030_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000078_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000041_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000086_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000051_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000014_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000056_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000035_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000083_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000029_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000036_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000015_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000008_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/ulm/ulm_000049_000019_leftImg8bit.png
#    creating: leftImg8bit/train/dusseldorf/
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000087_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000007_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000114_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000099_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000014_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000161_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000194_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000204_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000039_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000205_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000055_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000052_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000105_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000132_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000162_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000214_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000101_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000126_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000118_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000159_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000085_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000024_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000077_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000092_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000131_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000021_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000155_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000062_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000148_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000179_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000151_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000112_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000012_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000160_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000038_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000139_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000152_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000167_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000103_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000058_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000031_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000081_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000111_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000149_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000146_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000108_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000202_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000036_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000170_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000033_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000174_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000005_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000173_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000008_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000163_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000022_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000011_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000056_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000019_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000140_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000053_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000175_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000168_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000088_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000078_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000218_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000128_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000135_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000095_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000107_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000124_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000083_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000029_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000009_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000156_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000043_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000000_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000219_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000143_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000066_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000192_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000082_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000057_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000171_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000119_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000046_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000079_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000183_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000067_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000068_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000172_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000073_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000030_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000097_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000049_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000215_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000037_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000063_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000130_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000069_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000209_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000050_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000091_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000212_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000070_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000169_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000213_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000116_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000020_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000178_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000150_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000032_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000080_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000120_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000018_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000176_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000115_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000110_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000026_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000041_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000185_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000109_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000189_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000127_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000217_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000075_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000044_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000071_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000002_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000094_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000093_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000106_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000207_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000016_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000203_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000028_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000166_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000121_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000136_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000001_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000117_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000051_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000193_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000089_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000147_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000013_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000196_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000165_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000003_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000141_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000129_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000201_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000017_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000206_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000102_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000157_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000197_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000153_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000006_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000220_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000113_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000198_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000164_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000047_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000122_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000064_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000123_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000208_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000010_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000054_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000134_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000004_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000090_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000144_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000199_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000187_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000015_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000154_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000035_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000180_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000074_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000177_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000184_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000025_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000086_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000210_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000191_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000133_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000048_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000186_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000195_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000040_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000065_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000200_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000076_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000042_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000100_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000188_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000096_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000158_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000023_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000145_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000072_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000104_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000142_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000060_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000125_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000027_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000098_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000211_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000138_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000061_000019_leftImg8bit.png
#  extracting: leftImg8bit/train/dusseldorf/dusseldorf_000190_000019_leftImg8bit.png
# ...
#  extracting: leftImg8bit/test/munich/munich_000362_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000225_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000159_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000156_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000182_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000195_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000338_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000393_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000376_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000344_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000274_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000343_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000051_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000326_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000371_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000134_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000379_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000287_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000113_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000270_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000345_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000079_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000008_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000391_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000056_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000236_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000054_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000126_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000016_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000233_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000148_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000189_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000367_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000322_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000212_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000302_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000271_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000026_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000024_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000246_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000303_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000230_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000133_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000341_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000035_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000152_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000242_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000110_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000099_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000346_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000052_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000122_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000034_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000392_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000135_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000002_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000021_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000173_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000221_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000259_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000240_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000335_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000255_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000209_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000194_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000005_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000339_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000304_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000277_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000175_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000229_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000031_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000297_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000272_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000315_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000153_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000305_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000199_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000009_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000090_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000150_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000395_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000160_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000178_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000214_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000325_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000373_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000157_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000018_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000143_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000200_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000231_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000394_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000183_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000094_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000385_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000264_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000308_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000097_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000184_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000131_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000202_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000248_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000141_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000098_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000130_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000142_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000358_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000161_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000120_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000354_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000144_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000044_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000059_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000299_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000291_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000197_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000316_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000227_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000207_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000163_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000211_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000388_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000045_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000030_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000017_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000145_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000275_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000217_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000062_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000166_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000048_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000366_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000185_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000006_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000181_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000216_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000260_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000295_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000171_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000258_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000129_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000077_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000351_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000262_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000292_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000396_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000138_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000155_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000132_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000352_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000102_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000265_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000284_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000086_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000390_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000267_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000254_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000222_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000125_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000249_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000180_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000065_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000107_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000108_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000329_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000340_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000337_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000067_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000317_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000363_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000310_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000226_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000333_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000069_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000196_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000263_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000314_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000232_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000115_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000348_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000239_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000025_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000092_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000080_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000149_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000190_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000296_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000377_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000213_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000288_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000361_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000235_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000057_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000309_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000085_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000174_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000049_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000055_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000042_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000313_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000117_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000276_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000370_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000327_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000241_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000074_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000188_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000033_000019_leftImg8bit.png
#  extracting: leftImg8bit/test/munich/munich_000208_000019_leftImg8bit.png

# %% [markdown]
# # utils.py

# %%
import datetime
import errno
import os
import time
from collections import defaultdict, deque

import torch
import torch.distributed as dist


class SmoothedValue:
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device="cuda")
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median, avg=self.avg, global_avg=self.global_avg, max=self.max, value=self.value
        )


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]
    data_list = [None] * world_size
    dist.all_gather_object(data_list, data)
    return data_list


def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.inference_mode():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict


class MetricLogger:
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError(f"'{type(self).__name__}' object has no attribute '{attr}'")

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(f"{name}: {str(meter)}")
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ""
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt="{avg:.4f}")
        data_time = SmoothedValue(fmt="{avg:.4f}")
        space_fmt = ":" + str(len(str(len(iterable)))) + "d"
        if torch.cuda.is_available():
            log_msg = self.delimiter.join(
                [
                    header,
                    "[{0" + space_fmt + "}/{1}]",
                    "eta: {eta}",
                    "{meters}",
                    "time: {time}",
                    "data: {data}",
                    "max mem: {memory:.0f}",
                ]
            )
        else:
            log_msg = self.delimiter.join(
                [header, "[{0" + space_fmt + "}/{1}]", "eta: {eta}", "{meters}", "time: {time}", "data: {data}"]
            )
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(
                        log_msg.format(
                            i,
                            len(iterable),
                            eta=eta_string,
                            meters=str(self),
                            time=str(iter_time),
                            data=str(data_time),
                            memory=torch.cuda.max_memory_allocated() / MB,
                        )
                    )
                else:
                    print(
                        log_msg.format(
                            i, len(iterable), eta=eta_string, meters=str(self), time=str(iter_time), data=str(data_time)
                        )
                    )
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print(f"{header} Total time: {total_time_str} ({total_time / len(iterable):.4f} s / it)")


def collate_fn(batch):
    return tuple(zip(*batch))


def mkdir(path):
    try:
        os.makedirs(path)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise


def setup_for_distributed(is_master):
    """
    This function disables printing when not in master process
    """
    import builtins as __builtin__

    builtin_print = __builtin__.print

    def print(*args, **kwargs):
        force = kwargs.pop("force", False)
        if is_master or force:
            builtin_print(*args, **kwargs)

    __builtin__.print = print


def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True


def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()


def get_rank():
    if not is_dist_avail_and_initialized():
        return 0
    return dist.get_rank()


def is_main_process():
    return get_rank() == 0


def save_on_master(*args, **kwargs):
    if is_main_process():
        torch.save(*args, **kwargs)


def init_distributed_mode(args):
    if "RANK" in os.environ and "WORLD_SIZE" in os.environ:
        args.rank = int(os.environ["RANK"])
        args.world_size = int(os.environ["WORLD_SIZE"])
        args.gpu = int(os.environ["LOCAL_RANK"])
    elif "SLURM_PROCID" in os.environ:
        args.rank = int(os.environ["SLURM_PROCID"])
        args.gpu = args.rank % torch.cuda.device_count()
    else:
        print("Not using distributed mode")
        args.distributed = False
        return

    args.distributed = True

    torch.cuda.set_device(args.gpu)
    args.dist_backend = "nccl"
    print(f"| distributed init (rank {args.rank}): {args.dist_url}", flush=True)
    torch.distributed.init_process_group(
        backend=args.dist_backend, init_method=args.dist_url, world_size=args.world_size, rank=args.rank
    )
    torch.distributed.barrier()
    setup_for_distributed(args.rank == 0)

# %% [markdown]
# # coco-utils.py

# %%
import copy
import os

import torch
import torch.utils.data
import torchvision
import torchvision.transforms as T
from pycocotools import mask as coco_mask
from pycocotools.coco import COCO


class FilterAndRemapCocoCategories:
    def __init__(self, categories, remap=True):
        self.categories = categories
        self.remap = remap

    def __call__(self, image, target):
        anno = target["annotations"]
        anno = [obj for obj in anno if obj["category_id"] in self.categories]
        if not self.remap:
            target["annotations"] = anno
            return image, target
        anno = copy.deepcopy(anno)
        for obj in anno:
            obj["category_id"] = self.categories.index(obj["category_id"])
        target["annotations"] = anno
        return image, target


def convert_coco_poly_to_mask(segmentations, height, width):
    masks = []
    for polygons in segmentations:
        rles = coco_mask.frPyObjects(polygons, height, width)
        mask = coco_mask.decode(rles)
        if len(mask.shape) < 3:
            mask = mask[..., None]
        mask = torch.as_tensor(mask, dtype=torch.uint8)
        mask = mask.any(dim=2)
        masks.append(mask)
    if masks:
        masks = torch.stack(masks, dim=0)
    else:
        masks = torch.zeros((0, height, width), dtype=torch.uint8)
    return masks


class ConvertCocoPolysToMask:
    def __call__(self, image, target):
        w, h = image.size

        image_id = target["image_id"]
        image_id = torch.tensor([image_id])

        anno = target["annotations"]

        anno = [obj for obj in anno if obj["iscrowd"] == 0]

        boxes = [obj["bbox"] for obj in anno]
        # guard against no boxes via resizing
        boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
        boxes[:, 2:] += boxes[:, :2]
        boxes[:, 0::2].clamp_(min=0, max=w)
        boxes[:, 1::2].clamp_(min=0, max=h)

        classes = [obj["category_id"] for obj in anno]
        classes = torch.tensor(classes, dtype=torch.int64)

        segmentations = [obj["segmentation"] for obj in anno]
        masks = convert_coco_poly_to_mask(segmentations, h, w)

        keypoints = None
        if anno and "keypoints" in anno[0]:
            keypoints = [obj["keypoints"] for obj in anno]
            keypoints = torch.as_tensor(keypoints, dtype=torch.float32)
            num_keypoints = keypoints.shape[0]
            if num_keypoints:
                keypoints = keypoints.view(num_keypoints, -1, 3)

        keep = (boxes[:, 3] > boxes[:, 1]) & (boxes[:, 2] > boxes[:, 0])
        boxes = boxes[keep]
        classes = classes[keep]
        masks = masks[keep]
        if keypoints is not None:
            keypoints = keypoints[keep]

        target = {}
        target["boxes"] = boxes
        target["labels"] = classes
        target["masks"] = masks
        target["image_id"] = image_id
        if keypoints is not None:
            target["keypoints"] = keypoints

        # for conversion to coco api
        area = torch.tensor([obj["area"] for obj in anno])
        iscrowd = torch.tensor([obj["iscrowd"] for obj in anno])
        target["area"] = area
        target["iscrowd"] = iscrowd

        return image, target


def _coco_remove_images_without_annotations(dataset, cat_list=None):
    def _has_only_empty_bbox(anno):
        return all(any(o <= 1 for o in obj["bbox"][2:]) for obj in anno)

    def _count_visible_keypoints(anno):
        return sum(sum(1 for v in ann["keypoints"][2::3] if v > 0) for ann in anno)

    min_keypoints_per_image = 10

    def _has_valid_annotation(anno):
        # if it's empty, there is no annotation
        if len(anno) == 0:
            return False
        # if all boxes have close to zero area, there is no annotation
        if _has_only_empty_bbox(anno):
            return False
        # keypoints task have a slight different critera for considering
        # if an annotation is valid
        if "keypoints" not in anno[0]:
            return True
        # for keypoint detection tasks, only consider valid images those
        # containing at least min_keypoints_per_image
        if _count_visible_keypoints(anno) >= min_keypoints_per_image:
            return True
        return False

    assert isinstance(dataset, torchvision.datasets.CocoDetection)
    ids = []
    for ds_idx, img_id in enumerate(dataset.ids):
        ann_ids = dataset.coco.getAnnIds(imgIds=img_id, iscrowd=None)
        anno = dataset.coco.loadAnns(ann_ids)
        if cat_list:
            anno = [obj for obj in anno if obj["category_id"] in cat_list]
        if _has_valid_annotation(anno):
            ids.append(ds_idx)

    dataset = torch.utils.data.Subset(dataset, ids)
    return dataset


def convert_to_coco_api(ds):
    coco_ds = COCO()
    # annotation IDs need to start at 1, not 0, see torchvision issue #1530
    ann_id = 1
    dataset = {"images": [], "categories": [], "annotations": []}
    categories = set()
    for img_idx in range(len(ds)):
        # find better way to get target
        # targets = ds.get_annotations(img_idx)
        img, targets = ds[img_idx]
        image_id = targets["image_id"].item()
        img_dict = {}
        img_dict["id"] = image_id
        img_dict["height"] = img.shape[-2]
        img_dict["width"] = img.shape[-1]
        dataset["images"].append(img_dict)
        bboxes = targets["boxes"].clone()
        bboxes[:, 2:] -= bboxes[:, :2]
        bboxes = bboxes.tolist()
        labels = targets["labels"].tolist()
        areas = targets["area"].tolist()
        iscrowd = targets["iscrowd"].tolist()
        if "masks" in targets:
            masks = targets["masks"]
            # make masks Fortran contiguous for coco_mask
            masks = masks.permute(0, 2, 1).contiguous().permute(0, 2, 1)
        if "keypoints" in targets:
            keypoints = targets["keypoints"]
            keypoints = keypoints.reshape(keypoints.shape[0], -1).tolist()
        num_objs = len(bboxes)
        for i in range(num_objs):
            ann = {}
            ann["image_id"] = image_id
            ann["bbox"] = bboxes[i]
            ann["category_id"] = labels[i]
            categories.add(labels[i])
            ann["area"] = areas[i]
            ann["iscrowd"] = iscrowd[i]
            ann["id"] = ann_id
            if "masks" in targets:
                ann["segmentation"] = coco_mask.encode(masks[i].numpy())
            if "keypoints" in targets:
                ann["keypoints"] = keypoints[i]
                ann["num_keypoints"] = sum(k != 0 for k in keypoints[i][2::3])
            dataset["annotations"].append(ann)
            ann_id += 1
    dataset["categories"] = [{"id": i} for i in sorted(categories)]
    coco_ds.dataset = dataset
    coco_ds.createIndex()
    return coco_ds


def get_coco_api_from_dataset(dataset):
    for _ in range(10):
        if isinstance(dataset, torchvision.datasets.CocoDetection):
            break
        if isinstance(dataset, torch.utils.data.Subset):
            dataset = dataset.dataset
    if isinstance(dataset, torchvision.datasets.CocoDetection):
        return dataset.coco
    return convert_to_coco_api(dataset)


class CocoDetection(torchvision.datasets.CocoDetection):
    def __init__(self, img_folder, ann_file, transforms):
        super().__init__(img_folder, ann_file)
        self._transforms = transforms

    def __getitem__(self, idx):
        img, target = super().__getitem__(idx)
        image_id = self.ids[idx]
        target = dict(image_id=image_id, annotations=target)
        if self._transforms is not None:
            img, target = self._transforms(img, target)
        return img, target


def get_coco(root, image_set, transforms, mode="instances"):
    anno_file_template = "{}_{}2017.json"
    PATHS = {
        "train": ("train2017", os.path.join("annotations", anno_file_template.format(mode, "train"))),
        "val": ("val2017", os.path.join("annotations", anno_file_template.format(mode, "val"))),
        # "train": ("val2017", os.path.join("annotations", anno_file_template.format(mode, "val")))
    }

    t = [ConvertCocoPolysToMask()]

    if transforms is not None:
        t.append(transforms)
    transforms = T.Compose(t)

    img_folder, ann_file = PATHS[image_set]
    img_folder = os.path.join(root, img_folder)
    ann_file = os.path.join(root, ann_file)

    dataset = CocoDetection(img_folder, ann_file, transforms=transforms)

    if image_set == "train":
        dataset = _coco_remove_images_without_annotations(dataset)

    # dataset = torch.utils.data.Subset(dataset, [i for i in range(500)])

    return dataset


def get_coco_kp(root, image_set, transforms):
    return get_coco(root, image_set, transforms, mode="person_keypoints")


def get_cityscapes(root, ann_file, transforms):
    t = [ConvertCocoPolysToMask()]

    if transforms is not None:
        t.append(transforms)
    transforms = T.Compose(t)
    dataset = CocoDetection(root, ann_file, transforms=transforms)

    return dataset

# %% [markdown]
# # transforms.py

# %%
from typing import List, Tuple, Dict, Optional

import torch
import torchvision
from torch import nn, Tensor
from torchvision.transforms import functional as F
from torchvision.transforms import transforms as T, InterpolationMode


def _flip_coco_person_keypoints(kps, width):
    flip_inds = [0, 2, 1, 4, 3, 6, 5, 8, 7, 10, 9, 12, 11, 14, 13, 16, 15]
    flipped_data = kps[:, flip_inds]
    flipped_data[..., 0] = width - flipped_data[..., 0]
    # Maintain COCO convention that if visibility == 0, then x, y = 0
    inds = flipped_data[..., 2] == 0
    flipped_data[inds] = 0
    return flipped_data


class Compose:
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            image, target = t(image, target)
        return image, target


class RandomHorizontalFlip(T.RandomHorizontalFlip):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if torch.rand(1) < self.p:
            image = F.hflip(image)
            if target is not None:
                _, _, width = F.get_dimensions(image)
                target["boxes"][:, [0, 2]] = width - target["boxes"][:, [2, 0]]
                if "masks" in target:
                    target["masks"] = target["masks"].flip(-1)
                if "keypoints" in target:
                    keypoints = target["keypoints"]
                    keypoints = _flip_coco_person_keypoints(keypoints, width)
                    target["keypoints"] = keypoints
        return image, target


class ToTensor(nn.Module):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.pil_to_tensor(image)
        image = F.convert_image_dtype(image)
        return image, target


class PILToTensor(nn.Module):
    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.pil_to_tensor(image)
        return image, target


class ConvertImageDtype(nn.Module):
    def __init__(self, dtype: torch.dtype) -> None:
        super().__init__()
        self.dtype = dtype

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        image = F.convert_image_dtype(image, self.dtype)
        return image, target


class RandomIoUCrop(nn.Module):
    def __init__(
        self,
        min_scale: float = 0.3,
        max_scale: float = 1.0,
        min_aspect_ratio: float = 0.5,
        max_aspect_ratio: float = 2.0,
        sampler_options: Optional[List[float]] = None,
        trials: int = 40,
    ):
        super().__init__()
        # Configuration similar to https://github.com/weiliu89/caffe/blob/ssd/examples/ssd/ssd_coco.py#L89-L174
        self.min_scale = min_scale
        self.max_scale = max_scale
        self.min_aspect_ratio = min_aspect_ratio
        self.max_aspect_ratio = max_aspect_ratio
        if sampler_options is None:
            sampler_options = [0.0, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0]
        self.options = sampler_options
        self.trials = trials

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if target is None:
            raise ValueError("The targets can't be None for this transform.")

        if isinstance(image, torch.Tensor):
            if image.ndimension() not in {2, 3}:
                raise ValueError(f"image should be 2/3 dimensional. Got {image.ndimension()} dimensions.")
            elif image.ndimension() == 2:
                image = image.unsqueeze(0)

        _, orig_h, orig_w = F.get_dimensions(image)

        while True:
            # sample an option
            idx = int(torch.randint(low=0, high=len(self.options), size=(1,)))
            min_jaccard_overlap = self.options[idx]
            if min_jaccard_overlap >= 1.0:  # a value larger than 1 encodes the leave as-is option
                return image, target

            for _ in range(self.trials):
                # check the aspect ratio limitations
                r = self.min_scale + (self.max_scale - self.min_scale) * torch.rand(2)
                new_w = int(orig_w * r[0])
                new_h = int(orig_h * r[1])
                aspect_ratio = new_w / new_h
                if not (self.min_aspect_ratio <= aspect_ratio <= self.max_aspect_ratio):
                    continue

                # check for 0 area crops
                r = torch.rand(2)
                left = int((orig_w - new_w) * r[0])
                top = int((orig_h - new_h) * r[1])
                right = left + new_w
                bottom = top + new_h
                if left == right or top == bottom:
                    continue

                # check for any valid boxes with centers within the crop area
                cx = 0.5 * (target["boxes"][:, 0] + target["boxes"][:, 2])
                cy = 0.5 * (target["boxes"][:, 1] + target["boxes"][:, 3])
                is_within_crop_area = (left < cx) & (cx < right) & (top < cy) & (cy < bottom)
                if not is_within_crop_area.any():
                    continue

                # check at least 1 box with jaccard limitations
                boxes = target["boxes"][is_within_crop_area]
                ious = torchvision.ops.boxes.box_iou(
                    boxes, torch.tensor([[left, top, right, bottom]], dtype=boxes.dtype, device=boxes.device)
                )
                if ious.max() < min_jaccard_overlap:
                    continue

                # keep only valid boxes and perform cropping
                target["boxes"] = boxes
                target["labels"] = target["labels"][is_within_crop_area]
                target["boxes"][:, 0::2] -= left
                target["boxes"][:, 1::2] -= top
                target["boxes"][:, 0::2].clamp_(min=0, max=new_w)
                target["boxes"][:, 1::2].clamp_(min=0, max=new_h)
                image = F.crop(image, top, left, new_h, new_w)

                return image, target


class RandomZoomOut(nn.Module):
    def __init__(
        self, fill: Optional[List[float]] = None, side_range: Tuple[float, float] = (1.0, 4.0), p: float = 0.5
    ):
        super().__init__()
        if fill is None:
            fill = [0.0, 0.0, 0.0]
        self.fill = fill
        self.side_range = side_range
        if side_range[0] < 1.0 or side_range[0] > side_range[1]:
            raise ValueError(f"Invalid canvas side range provided {side_range}.")
        self.p = p

    @torch.jit.unused
    def _get_fill_value(self, is_pil):
        # type: (bool) -> int
        # We fake the type to make it work on JIT
        return tuple(int(x) for x in self.fill) if is_pil else 0

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if isinstance(image, torch.Tensor):
            if image.ndimension() not in {2, 3}:
                raise ValueError(f"image should be 2/3 dimensional. Got {image.ndimension()} dimensions.")
            elif image.ndimension() == 2:
                image = image.unsqueeze(0)

        if torch.rand(1) >= self.p:
            return image, target

        _, orig_h, orig_w = F.get_dimensions(image)

        r = self.side_range[0] + torch.rand(1) * (self.side_range[1] - self.side_range[0])
        canvas_width = int(orig_w * r)
        canvas_height = int(orig_h * r)

        r = torch.rand(2)
        left = int((canvas_width - orig_w) * r[0])
        top = int((canvas_height - orig_h) * r[1])
        right = canvas_width - (left + orig_w)
        bottom = canvas_height - (top + orig_h)

        if torch.jit.is_scripting():
            fill = 0
        else:
            fill = self._get_fill_value(F._is_pil_image(image))

        image = F.pad(image, [left, top, right, bottom], fill=fill)
        if isinstance(image, torch.Tensor):
            # PyTorch's pad supports only integers on fill. So we need to overwrite the colour
            v = torch.tensor(self.fill, device=image.device, dtype=image.dtype).view(-1, 1, 1)
            image[..., :top, :] = image[..., :, :left] = image[..., (top + orig_h) :, :] = image[
                ..., :, (left + orig_w) :
            ] = v

        if target is not None:
            target["boxes"][:, 0::2] += left
            target["boxes"][:, 1::2] += top

        return image, target


class RandomPhotometricDistort(nn.Module):
    def __init__(
        self,
        contrast: Tuple[float] = (0.5, 1.5),
        saturation: Tuple[float] = (0.5, 1.5),
        hue: Tuple[float] = (-0.05, 0.05),
        brightness: Tuple[float] = (0.875, 1.125),
        p: float = 0.5,
    ):
        super().__init__()
        self._brightness = T.ColorJitter(brightness=brightness)
        self._contrast = T.ColorJitter(contrast=contrast)
        self._hue = T.ColorJitter(hue=hue)
        self._saturation = T.ColorJitter(saturation=saturation)
        self.p = p

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if isinstance(image, torch.Tensor):
            if image.ndimension() not in {2, 3}:
                raise ValueError(f"image should be 2/3 dimensional. Got {image.ndimension()} dimensions.")
            elif image.ndimension() == 2:
                image = image.unsqueeze(0)

        r = torch.rand(7)

        if r[0] < self.p:
            image = self._brightness(image)

        contrast_before = r[1] < 0.5
        if contrast_before:
            if r[2] < self.p:
                image = self._contrast(image)

        if r[3] < self.p:
            image = self._saturation(image)

        if r[4] < self.p:
            image = self._hue(image)

        if not contrast_before:
            if r[5] < self.p:
                image = self._contrast(image)

        if r[6] < self.p:
            channels, _, _ = F.get_dimensions(image)
            permutation = torch.randperm(channels)

            is_pil = F._is_pil_image(image)
            if is_pil:
                image = F.pil_to_tensor(image)
                image = F.convert_image_dtype(image)
            image = image[..., permutation, :, :]
            if is_pil:
                image = F.to_pil_image(image)

        return image, target


class ScaleJitter(nn.Module):
    """Randomly resizes the image and its bounding boxes  within the specified scale range.
    The class implements the Scale Jitter augmentation as described in the paper
    `"Simple Copy-Paste is a Strong Data Augmentation Method for Instance Segmentation" <https://arxiv.org/abs/2012.07177>`_.
    Args:
        target_size (tuple of ints): The target size for the transform provided in (height, weight) format.
        scale_range (tuple of ints): scaling factor interval, e.g (a, b), then scale is randomly sampled from the
            range a <= scale <= b.
        interpolation (InterpolationMode): Desired interpolation enum defined by
            :class:`torchvision.transforms.InterpolationMode`. Default is ``InterpolationMode.BILINEAR``.
    """

    def __init__(
        self,
        target_size: Tuple[int, int],
        scale_range: Tuple[float, float] = (0.1, 2.0),
        interpolation: InterpolationMode = InterpolationMode.BILINEAR,
    ):
        super().__init__()
        self.target_size = target_size
        self.scale_range = scale_range
        self.interpolation = interpolation

    def forward(
        self, image: Tensor, target: Optional[Dict[str, Tensor]] = None
    ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        if isinstance(image, torch.Tensor):
            if image.ndimension() not in {2, 3}:
                raise ValueError(f"image should be 2/3 dimensional. Got {image.ndimension()} dimensions.")
            elif image.ndimension() == 2:
                image = image.unsqueeze(0)

        _, orig_height, orig_width = F.get_dimensions(image)

        r = self.scale_range[0] + torch.rand(1) * (self.scale_range[1] - self.scale_range[0])
        new_width = int(self.target_size[1] * r)
        new_height = int(self.target_size[0] * r)

        image = F.resize(image, [new_height, new_width], interpolation=self.interpolation)

        if target is not None:
            target["boxes"][:, 0::2] *= new_width / orig_width
            target["boxes"][:, 1::2] *= new_height / orig_height
            if "masks" in target:
                target["masks"] = F.resize(
                    target["masks"], [new_height, new_width], interpolation=InterpolationMode.NEAREST
                )

        return image, target

# %% [markdown]
# # coco-eval.py

# %%
import copy
import io
from contextlib import redirect_stdout

import numpy as np
import pycocotools.mask as mask_util
import torch
# import utils
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval


class CocoEvaluator:
    def __init__(self, coco_gt, iou_types):
        assert isinstance(iou_types, (list, tuple))
        coco_gt = copy.deepcopy(coco_gt)
        self.coco_gt = coco_gt

        self.iou_types = iou_types
        self.coco_eval = {}
        for iou_type in iou_types:
            self.coco_eval[iou_type] = COCOeval(coco_gt, iouType=iou_type)

        self.img_ids = []
        self.eval_imgs = {k: [] for k in iou_types}

    def update(self, predictions):
        img_ids = list(np.unique(list(predictions.keys())))
        self.img_ids.extend(img_ids)

        for iou_type in self.iou_types:
            results = self.prepare(predictions, iou_type)
            with redirect_stdout(io.StringIO()):
                coco_dt = COCO.loadRes(self.coco_gt, results) if results else COCO()
            coco_eval = self.coco_eval[iou_type]

            coco_eval.cocoDt = coco_dt
            coco_eval.params.imgIds = list(img_ids)
            img_ids, eval_imgs = evaluate(coco_eval)

            self.eval_imgs[iou_type].append(eval_imgs)

    def synchronize_between_processes(self):
        for iou_type in self.iou_types:
            self.eval_imgs[iou_type] = np.concatenate(self.eval_imgs[iou_type], 2)
            create_common_coco_eval(self.coco_eval[iou_type], self.img_ids, self.eval_imgs[iou_type])

    def accumulate(self):
        for coco_eval in self.coco_eval.values():
            coco_eval.accumulate()

    def summarize(self):
        for iou_type, coco_eval in self.coco_eval.items():
            print(f"IoU metric: {iou_type}")
            coco_eval.summarize()

    def prepare(self, predictions, iou_type):
        if iou_type == "bbox":
            return self.prepare_for_coco_detection(predictions)
        if iou_type == "segm":
            return self.prepare_for_coco_segmentation(predictions)
        if iou_type == "keypoints":
            return self.prepare_for_coco_keypoint(predictions)
        raise ValueError(f"Unknown iou type {iou_type}")

    def prepare_for_coco_detection(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "bbox": box,
                        "score": scores[k],
                    }
                    for k, box in enumerate(boxes)
                ]
            )
        return coco_results

    def prepare_for_coco_segmentation(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            scores = prediction["scores"]
            labels = prediction["labels"]
            masks = prediction["masks"]

            masks = masks > 0.5

            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()

            rles = [
                mask_util.encode(np.array(mask[0, :, :, np.newaxis], dtype=np.uint8, order="F"))[0] for mask in masks
            ]
            for rle in rles:
                rle["counts"] = rle["counts"].decode("utf-8")

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "segmentation": rle,
                        "score": scores[k],
                    }
                    for k, rle in enumerate(rles)
                ]
            )
        return coco_results

    def prepare_for_coco_keypoint(self, predictions):
        coco_results = []
        for original_id, prediction in predictions.items():
            if len(prediction) == 0:
                continue

            boxes = prediction["boxes"]
            boxes = convert_to_xywh(boxes).tolist()
            scores = prediction["scores"].tolist()
            labels = prediction["labels"].tolist()
            keypoints = prediction["keypoints"]
            keypoints = keypoints.flatten(start_dim=1).tolist()

            coco_results.extend(
                [
                    {
                        "image_id": original_id,
                        "category_id": labels[k],
                        "keypoints": keypoint,
                        "score": scores[k],
                    }
                    for k, keypoint in enumerate(keypoints)
                ]
            )
        return coco_results


def convert_to_xywh(boxes):
    xmin, ymin, xmax, ymax = boxes.unbind(1)
    return torch.stack((xmin, ymin, xmax - xmin, ymax - ymin), dim=1)


def merge(img_ids, eval_imgs):
    all_img_ids = utils.all_gather(img_ids)
    all_eval_imgs = utils.all_gather(eval_imgs)

    merged_img_ids = []
    for p in all_img_ids:
        merged_img_ids.extend(p)

    merged_eval_imgs = []
    for p in all_eval_imgs:
        merged_eval_imgs.append(p)

    merged_img_ids = np.array(merged_img_ids)
    merged_eval_imgs = np.concatenate(merged_eval_imgs, 2)

    # keep only unique (and in sorted order) images
    merged_img_ids, idx = np.unique(merged_img_ids, return_index=True)
    merged_eval_imgs = merged_eval_imgs[..., idx]

    return merged_img_ids, merged_eval_imgs


def create_common_coco_eval(coco_eval, img_ids, eval_imgs):
    img_ids, eval_imgs = merge(img_ids, eval_imgs)
    img_ids = list(img_ids)
    eval_imgs = list(eval_imgs.flatten())

    coco_eval.evalImgs = eval_imgs
    coco_eval.params.imgIds = img_ids
    coco_eval._paramsEval = copy.deepcopy(coco_eval.params)


def evaluate(imgs):
    with redirect_stdout(io.StringIO()):
        imgs.evaluate()
    return imgs.params.imgIds, np.asarray(imgs.evalImgs).reshape(-1, len(imgs.params.areaRng), len(imgs.params.imgIds))

# %% [markdown]
# # engine.py

# %%
import math
import sys
import time

import torch
import torchvision.models.detection.mask_rcnn
# import utils
# from coco_eval import CocoEvaluator
# from coco_utils import get_coco_api_from_dataset


def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler=None):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter("lr", SmoothedValue(window_size=1, fmt="{value:.6f}"))
    header = f"Epoch: [{epoch}]"

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1.0 / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = torch.optim.lr_scheduler.LinearLR(
            optimizer, start_factor=warmup_factor, total_iters=warmup_iters
        )

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        target = [t for t in targets]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        with torch.cuda.amp.autocast(enabled=scaler is not None):
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        loss_value = losses_reduced.item()

        if not math.isfinite(loss_value):
            print(f"Loss is {loss_value}, stopping training")
            print(loss_dict_reduced)
            sys.exit(1)

        optimizer.zero_grad()
        if scaler is not None:
            scaler.scale(losses).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            losses.backward()
            optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

    return metric_logger


def _get_iou_types(model):
    model_without_ddp = model
    if isinstance(model, torch.nn.parallel.DistributedDataParallel):
        model_without_ddp = model.module
    iou_types = ["bbox"]
    if isinstance(model_without_ddp, torchvision.models.detection.MaskRCNN):
        iou_types.append("segm")
    if isinstance(model_without_ddp, torchvision.models.detection.KeypointRCNN):
        iou_types.append("keypoints")
    return iou_types


@torch.inference_mode()
def evaluate(model, data_loader, device):
    n_threads = torch.get_num_threads()
    # FIXME remove this and make paste_masks_in_image run on the GPU
    torch.set_num_threads(1)
    cpu_device = torch.device("cpu")
    model.eval()
    metric_logger = MetricLogger(delimiter="  ")
    header = "Test:"

    coco = get_coco_api_from_dataset(data_loader.dataset)
    iou_types = _get_iou_types(model)
    coco_evaluator = CocoEvaluator(coco, iou_types)

    for images, targets in metric_logger.log_every(data_loader, 100, header):
        images = list(img.to(device) for img in images)

        if torch.cuda.is_available():
            torch.cuda.synchronize()
        model_time = time.time()
        outputs = model(images)

        outputs = [{k: v.to(cpu_device) for k, v in t.items()} for t in outputs]
        model_time = time.time() - model_time

        res = {target["image_id"].item(): output for target, output in zip(targets, outputs)}
        evaluator_time = time.time()
        coco_evaluator.update(res)
        evaluator_time = time.time() - evaluator_time
        metric_logger.update(model_time=model_time, evaluator_time=evaluator_time)

    # gather the stats from all processes
    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    coco_evaluator.synchronize_between_processes()

    # accumulate predictions from all images
    coco_evaluator.accumulate()
    coco_evaluator.summarize()
    torch.set_num_threads(n_threads)
    return coco_evaluator

# %% [markdown]
# # Cityscape run on mask rcnn

# %%
import torch
import torchvision
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.datasets import Cityscapes


print('Loading pretrained model...')
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True).cuda()
model.eval()
# Out:
# Loading pretrained model...
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 91, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
import os
import random
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torchvision.transforms.functional as TF
from collections import namedtuple


class CityscapesDataset(Dataset):

    def __init__(self, root, split='train', mode='fine', augment=False):

        self.root = os.path.expanduser(root)
        self.mode = 'gtFine' if mode == 'fine' else 'gtCoarse'
        self.images_dir = os.path.join(self.root, 'leftImg8bit', split)
        self.targets_dir = os.path.join(self.root, self.mode, split)
        print(self.images_dir)
        print(self.targets_dir)
        self.split = split
        self.augment = augment
        self.images = []
        self.targets = []
        self.mapping = {
            0: 0,  # unlabeled
            1: 0,  # ego vehicle
            2: 0,  # rect border
            3: 0,  # out of roi
            4: 0,  # static
            5: 0,  # dynamic
            6: 0,  # ground
            7: 1,  # road
            8: 0,  # sidewalk
            9: 0,  # parking
            10: 0,  # rail track
            11: 0,  # building
            12: 0,  # wall
            13: 0,  # fence
            14: 0,  # guard rail
            15: 0,  # bridge
            16: 0,  # tunnel
            17: 0,  # pole
            18: 0,  # polegroup
            19: 0,  # traffic light
            20: 0,  # traffic sign
            21: 0,  # vegetation
            22: 0,  # terrain
            23: 2,  # sky
            24: 0,  # person
            25: 0,  # rider
            26: 3,  # car
            27: 0,  # truck
            28: 0,  # bus
            29: 0,  # caravan
            30: 0,  # trailer
            31: 0,  # train
            32: 0,  # motorcycle
            33: 0,  # bicycle
            -1: 0  # licenseplate
        }
        self.mappingrgb = {
            0: (255, 0, 0),  # unlabeled
            1: (255, 0, 0),  # ego vehicle
            2: (255, 0, 0),  # rect border
            3: (255, 0, 0),  # out of roi
            4: (255, 0, 0),  # static
            5: (255, 0, 0),  # dynamic
            6: (255, 0, 0),  # ground
            7: (0, 255, 0),  # road
            8: (255, 0, 0),  # sidewalk
            9: (255, 0, 0),  # parking
            10: (255, 0, 0),  # rail track
            11: (255, 0, 0),  # building
            12: (255, 0, 0),  # wall
            13: (255, 0, 0),  # fence
            14: (255, 0, 0),  # guard rail
            15: (255, 0, 0),  # bridge
            16: (255, 0, 0),  # tunnel
            17: (255, 0, 0),  # pole
            18: (255, 0, 0),  # polegroup
            19: (255, 0, 0),  # traffic light
            20: (255, 0, 0),  # traffic sign
            21: (255, 0, 0),  # vegetation
            22: (255, 0, 0),  # terrain
            23: (0, 0, 255),  # sky
            24: (255, 0, 0),  # person
            25: (255, 0, 0),  # rider
            26: (255, 255, 0),  # car
            27: (255, 0, 0),  # truck
            28: (255, 0, 0),  # bus
            29: (255, 0, 0),  # caravan
            30: (255, 0, 0),  # trailer
            31: (255, 0, 0),  # train
            32: (255, 0, 0),  # motorcycle
            33: (255, 0, 0),  # bicycle
            -1: (255, 0, 0)  # licenseplate
        }

        # Ensure that this matches the above mapping!#!@#!@#
        # For example 4 classes, means we should map to the ids=(0,1,2,3)
        # This is used to specify how many outputs the network should product...
        self.num_classes = 4

        # =============================================
        # Check that inputs are valid
        # =============================================
        if mode not in ['fine', 'coarse']:
            raise ValueError('Invalid mode! Please use mode="fine" or mode="coarse"')
        if mode == 'fine' and split not in ['train', 'test', 'val']:
            raise ValueError('Invalid split for mode "fine"! Please use split="train", split="test" or split="val"')
        elif mode == 'coarse' and split not in ['train', 'train_extra', 'val']:
            raise ValueError('Invalid split for mode "coarse"! Please use split="train", split="train_extra" or split="val"')
        if not os.path.isdir(self.images_dir) or not os.path.isdir(self.targets_dir):
            raise RuntimeError('Dataset not found or incomplete. Please make sure all required folders for the'
                               ' specified "split" and "mode" are inside the "root" directory')

        # =============================================
        # Read in the paths to all images
        # =============================================
        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            target_dir = os.path.join(self.targets_dir, city)
            for file_name in os.listdir(img_dir):
                self.images.append(os.path.join(img_dir, file_name))
                target_name = '{}_{}'.format(file_name.split('_leftImg8bit')[0], '{}_labelIds.png'.format(self.mode))
                # target_name = '{}_{}'.format(file_name.split('_leftImg8bit')[0], '{}_color.png'.format(self.mode))
                self.targets.append(os.path.join(target_dir, target_name))

    def __repr__(self):
        fmt_str = 'Dataset ' + self.__class__.__name__ + '\n'
        fmt_str += '    Number of images: {}\n'.format(self.__len__())
        fmt_str += '    Split: {}\n'.format(self.split)
        fmt_str += '    Mode: {}\n'.format(self.mode)
        fmt_str += '    Augment: {}\n'.format(self.augment)
        fmt_str += '    Root Location: {}\n'.format(self.root)
        return fmt_str

    def __len__(self):
        return len(self.images)

    def mask_to_class(self, mask):
        '''
        Given the cityscapes dataset, this maps to a 0..classes numbers.
        This is because we are using a subset of all masks, so we have this "mapping" function.
        This mapping function is used to map all the standard ids into the smaller subset.
        '''
        maskimg = torch.zeros((mask.size()[0], mask.size()[1]), dtype=torch.uint8)
        for k in self.mapping:
            maskimg[mask == k] = self.mapping[k]
        return maskimg

    def mask_to_rgb(self, mask):
        '''
        Given the Cityscapes mask file, this converts the ids into rgb colors.
        This is needed as we are interested in a sub-set of labels, thus can't just use the
        standard color output provided by the dataset.
        '''
        rgbimg = torch.zeros((3, mask.size()[0], mask.size()[1]), dtype=torch.uint8)
        for k in self.mappingrgb:
            rgbimg[0][mask == k] = self.mappingrgb[k][0]
            rgbimg[1][mask == k] = self.mappingrgb[k][1]
            rgbimg[2][mask == k] = self.mappingrgb[k][2]
        return rgbimg

    def class_to_rgb(self, mask):
        '''
        This function maps the classification index ids into the rgb.
        For example after the argmax from the network, you want to find what class
        a given pixel belongs too. This does that but just changes the color
        so that we can compare it directly to the rgb groundtruth label.
        '''
        mask2class = dict((v, k) for k, v in self.mapping.items())
        rgbimg = torch.zeros((3, mask.size()[0], mask.size()[1]), dtype=torch.uint8)
        for k in mask2class:
            rgbimg[0][mask == k] = self.mappingrgb[mask2class[k]][0]
            rgbimg[1][mask == k] = self.mappingrgb[mask2class[k]][1]
            rgbimg[2][mask == k] = self.mappingrgb[mask2class[k]][2]
        return rgbimg

    def __getitem__(self, index):

        # first load the RGB image
        image = Image.open(self.images[index]).convert('RGB')

        # next load the target
        target = Image.open(self.targets[index]).convert('L')

        # If augmenting, apply random transforms
        # Else we should just resize the image down to the correct size
        # if self.augment:
        #     # Resize
        #     image = TF.resize(image, size=(128+10, 256+10), interpolation=Image.BILINEAR)
        #     target = TF.resize(target, size=(128+10, 256+10), interpolation=Image.NEAREST)
        #     # Random crop
        #     i, j, h, w = transforms.RandomCrop.get_params(image, output_size=(128, 256))
        #     image = TF.crop(image, i, j, h, w)
        #     target = TF.crop(target, i, j, h, w)
        #     # Random horizontal flipping
        #     if random.random() > 0.5:
        #         image = TF.hflip(image)
        #         target = TF.hflip(target)
        #     # Random vertical flipping
        #     # (I found this caused issues with the sky=road during prediction)
        #     # if random.random() > 0.5:
        #     #    image = TF.vflip(image)
        #     #    target = TF.vflip(target)
        # else:
        #     # Resize
        #     image = TF.resize(image, size=(128, 256), interpolation=Image.BILINEAR)
        #     target = TF.resize(target, size=(128, 256), interpolation=Image.NEAREST)

        # convert to pytorch tensors
        # target = TF.to_tensor(target)
        target = torch.from_numpy(np.array(target, dtype=np.uint8))
        image = TF.to_tensor(image)

        # convert the labels into a mask
        targetrgb = self.mask_to_rgb(target)
        targetmask = self.mask_to_class(target)
        targetmask = targetmask.long()
        targetrgb = targetrgb.long()

        # finally return the image pair
        # return image, targetmask, targetrgb
        return image, targetmask

# %%
ls
# Out:
#  20201112_072342.jpg         data/             Masked-R-CNN.ipynb
#  AlexNet.ipynb               GAN.ipynb        'Resnet&SEnet.ipynb'
#  cityscape_mask_rcnn.ipynb   GoogLeNet.ipynb   YOLO.ipynb
#  Collection.ipynb            List.gdoc

# %%
cd /content/drive/MyDrive/RTML/Midsem_prep
# Out:
# /content/drive/MyDrive/RTML/Midsem_prep

# %%
cityscapes_path = "data/"

print('Loading Cityscapes val datasets...')
dataset = CityscapesDataset(cityscapes_path, split='val', mode='fine', augment=False)

print(dataset)

val_dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=True, num_workers=2)
# Out:
# Loading Cityscapes val datasets...
# data/leftImg8bit/val
# data/gtFine/val
# Dataset CityscapesDataset
#     Number of images: 500
#     Split: val
#     Mode: gtFine
#     Augment: False
#     Root Location: data/

# %%
images, targetmask = next(iter(val_dataloader))
print(images.shape)
print(targetmask.shape)

images = [ img.cuda() for img in images ]
print(type(images))
print(images)
predictions = model(images)


print('Prediction keys:', predictions[0].keys())
print('Boxes shape:', predictions[0]['boxes'].shape)
print('Labels shape:', predictions[0]['labels'].shape)
print('Scores shape:', predictions[0]['scores'].shape)
print('Masks shape:', predictions[0]['masks'].shape)
# Out:
# torch.Size([1, 3, 1024, 2048])
# torch.Size([1, 1024, 2048])
# <class 'list'>
# [tensor([[[0.3804, 0.3686, 0.3686,  ..., 0.2745, 0.2784, 0.2745],
#          [0.3608, 0.3608, 0.3608,  ..., 0.2784, 0.2745, 0.2706],
#          [0.3412, 0.3490, 0.3490,  ..., 0.2784, 0.2706, 0.2627],
#          ...,
#          [0.2039, 0.1961, 0.1922,  ..., 0.1608, 0.1608, 0.1569],
#          [0.2039, 0.1961, 0.1922,  ..., 0.1725, 0.1686, 0.1608],
#          [0.2039, 0.1961, 0.1922,  ..., 0.1843, 0.1843, 0.1804]],
#
#         [[0.3843, 0.3843, 0.3922,  ..., 0.2902, 0.2863, 0.2824],
#          [0.3922, 0.4039, 0.4039,  ..., 0.2902, 0.2863, 0.2824],
#          [0.4000, 0.4118, 0.4157,  ..., 0.2863, 0.2784, 0.2745],
#          ...,
#          [0.2588, 0.2588, 0.2588,  ..., 0.2078, 0.2078, 0.2078],
#          [0.2588, 0.2588, 0.2588,  ..., 0.2196, 0.2157, 0.2078],
#          [0.2588, 0.2588, 0.2588,  ..., 0.2314, 0.2314, 0.2275]],
#
#         [[0.3255, 0.3255, 0.3137,  ..., 0.2353, 0.2314, 0.2235],
#          [0.3412, 0.3608, 0.3490,  ..., 0.2314, 0.2275, 0.2196],
#          [0.3569, 0.3725, 0.3765,  ..., 0.2275, 0.2235, 0.2157],
#          ...,
#          [0.2275, 0.2235, 0.2275,  ..., 0.1765, 0.1765, 0.1765],
#          [0.2275, 0.2235, 0.2275,  ..., 0.1882, 0.1843, 0.1725],
#          [0.2275, 0.2235, 0.2275,  ..., 0.2039, 0.2000, 0.1961]]],
#        device='cuda:0')]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Prediction keys: dict_keys(['boxes', 'labels', 'scores', 'masks'])
# Boxes shape: torch.Size([56, 4])
# Labels shape: torch.Size([56])
# Scores shape: torch.Size([56])
# Masks shape: torch.Size([56, 1, 1024, 2048])

# %%
import numpy as np
import cv2
import random

# Array of labels for COCO dataset (91 elements)

coco_names = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Random colors to use for labeling objects

COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3)).astype(np.uint8)

# Overlay masks, bounding boxes, and labels on input numpy image

def draw_segmentation_map(image, masks, boxes, labels):
    alpha = 1
    beta = 0.5 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # convert from RGB to OpenCV BGR format
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    for i in range(len(masks)):
        mask = masks[i,:,:]
        red_map = np.zeros_like(mask).astype(np.uint8)
        green_map = np.zeros_like(mask).astype(np.uint8)
        blue_map = np.zeros_like(mask).astype(np.uint8)
        # apply a randon color mask to each object
        color = COLORS[random.randrange(0, len(COLORS))]
        red_map[mask > 0.5] = color[0]
        green_map[mask > 0.5] = color[1]
        blue_map[mask > 0.5] = color[2]
        # combine all the masks into a single image
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
        # apply colored mask to the image
        image = cv2.addWeighted(image, alpha, segmentation_map, beta, gamma)
        # draw the bounding box around each object
        p1 = (int(boxes[i][0]), int(boxes[i][1]))
        p2 = (int(boxes[i][2]), int(boxes[i][3]))
        color = (int(color[0]), int(color[1]), int(color[2]))
        cv2.rectangle(image, p1, p2, color, 2)
        # put the label text above the objects
        p = (int(boxes[i][0]), int(boxes[i][1]-10))
        cv2.putText(image, labels[i], p, cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Overlay masks, bounding boxes, and labels of objects with scores greater than
# threshold on one of the images in the input tensor using the predictions output by Mask R-CNN.

def prediction_to_mask_image(images, predictions, img_index, threshold):
    scores = predictions[img_index]['scores']
    boxes_to_use = scores >= threshold
    img = (images[img_index].cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    masks = predictions[img_index]['masks'][boxes_to_use, :, :].cpu().detach().squeeze(1).numpy()
    boxes = predictions[img_index]['boxes'][boxes_to_use, :].cpu().detach().numpy()
    labels = predictions[img_index]['labels'][boxes_to_use].cpu().numpy()
    labels = [ coco_names[l] for l in labels ]

    return draw_segmentation_map(img, masks, boxes, labels)

# %%
from matplotlib import pyplot as plt

masked_img = prediction_to_mask_image(images, predictions, 0, 0.5)
plt.figure(1, figsize=(12, 9), dpi=100)
plt.imshow(masked_img)
plt.title('Validation image result')
plt.show()

# %% [markdown]
# # coco-finetune

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/         run/   tensorflow-1.15.2/  var/
# boot/     etc/   lib64/  proc/        sbin/  tmp/
# content/  home/  media/  python-apt/  srv/   tools/
# datalab/  lib/   mnt/    root/        sys/   usr/

# %%
cityscapes_path = "data/"

print('Loading Cityscapes val datasets...')
train_dataset = CityscapesDataset(cityscapes_path, split='train', mode='fine', augment=False)
val_dataset = CityscapesDataset(cityscapes_path, split='val', mode='fine', augment=False)

print('train dataset')
print(train_dataset)
print('val dataset')
print(val_dataset)

# train_dataset = get_cityscapes()

# def collate_fn(batch):
#     return tuple(zip(*batch))

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=2, collate_fn = collate_fn)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=True, num_workers=2, collate_fn = collate_fn)
# Out:
# Loading Cityscapes val datasets...
# data/leftImg8bit/train
# data/gtFine/train
# data/leftImg8bit/val
# data/gtFine/val
# train dataset
# Dataset CityscapesDataset
#     Number of images: 2975
#     Split: train
#     Mode: gtFine
#     Augment: False
#     Root Location: data/
#
# val dataset
# Dataset CityscapesDataset
#     Number of images: 500
#     Split: val
#     Mode: gtFine
#     Augment: False
#     Root Location: data/

# %%
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from PIL import Image

num_classes = 91

print('loading pretrained model')
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

# Modify model for the given number of classes

in_features = model.roi_heads.box_predictor.cls_score.in_features
num_classes = 8

model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256
model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

model.cuda()
# Out:
# loading pretrained model
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=8, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=32, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt

# Array of labels for COCO dataset (91 elements)

coco_names = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Random colors to use for labeling objects

COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3)).astype(np.uint8)

# Overlay masks, bounding boxes, and labels on input numpy image

def draw_segmentation_map(image, masks, boxes, labels):
    alpha = 1
    beta = 0.5 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # convert from RGB to OpenCV BGR format
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    for i in range(len(masks)):
        mask = masks[i,:,:]
        red_map = np.zeros_like(mask).astype(np.uint8)
        green_map = np.zeros_like(mask).astype(np.uint8)
        blue_map = np.zeros_like(mask).astype(np.uint8)
        # apply a randon color mask to each object
        color = COLORS[random.randrange(0, len(COLORS))]
        red_map[mask > 0.5] = color[0]
        green_map[mask > 0.5] = color[1]
        blue_map[mask > 0.5] = color[2]
        # combine all the masks into a single image
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
        # apply colored mask to the image
        image = cv2.addWeighted(image, alpha, segmentation_map, beta, gamma)
        # draw the bounding box around each object
        p1 = (int(boxes[i][0]), int(boxes[i][1]))
        p2 = (int(boxes[i][2]), int(boxes[i][3]))
        color = (int(color[0]), int(color[1]), int(color[2]))
        cv2.rectangle(image, p1, p2, color, 2)
        # put the label text above the objects
        p = (int(boxes[i][0]), int(boxes[i][1]-10))
        cv2.putText(image, labels[i], p, cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Overlay masks, bounding boxes, and labels of objects with scores greater than
# threshold on one of the images in the input tensor using the predictions output by Mask R-CNN.

def prediction_to_mask_image(images, predictions, img_index, threshold):
    scores = predictions[img_index]['scores']
    boxes_to_use = scores >= threshold
    img = (images[img_index].cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    masks = predictions[img_index]['masks'][boxes_to_use, :, :].cpu().detach().squeeze(1).numpy()
    boxes = predictions[img_index]['boxes'][boxes_to_use, :].cpu().detach().numpy()
    labels = predictions[img_index]['labels'][boxes_to_use].cpu().numpy()
    labels = [ coco_names[l] for l in labels ]

    return draw_segmentation_map(img, masks, boxes, labels)

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# print(device)


# # Training
# params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# # and a learning rate scheduler
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=3,gamma=0.1)
# num_epochs = 10
# for epoch in range(num_epochs):
#     # train for one epoch, printing every 10 iterations
#     train_one_epoch(model, optimizer, train_dataloader, device, epoch, print_freq=10)
#     torch.save(model.state_dict(), ('cityscape-finetune-Mask-Rcnn-%02d-epochs.pth' % epoch))
#     lr_scheduler.step()
#     evaluate(model, val_dataloader, device=device)

# # for images, targets in train_dataloader:
# #     images = list(image.to(device) for image in images)
# #     targets = [{k: v for k, v in t.items()} for t in targets]
# #     output = model(images,targets)   # Returns losses and detections
# #     print(output)
# #     break

# %% [markdown]
# # Inference

# %%
# !wget https://www.cs.ait.ac.th/~mdailey/20201112_072342.jpg
# Out:
# --2022-03-03 14:24:40--  https://www.cs.ait.ac.th/~mdailey/20201112_072342.jpg
# Resolving www.cs.ait.ac.th (www.cs.ait.ac.th)... 192.41.170.42
# Connecting to www.cs.ait.ac.th (www.cs.ait.ac.th)|192.41.170.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3320786 (3.2M) [image/jpeg]
# Saving to: ‘20201112_072342.jpg.1’
#
# 20201112_072342.jpg 100%[===================>]   3.17M   867KB/s    in 3.7s
#
# 2022-03-03 14:24:45 (867 KB/s) - ‘20201112_072342.jpg.1’ saved [3320786/3320786]

# %%
# im = Image.open('20201112_072342.jpg').rotate(180)

# import torchvision.transforms as T

# transform = T.ToTensor()
# image_batch = transform(im).unsqueeze(0)
# image_batch.shape

# predictions = model(image_batch)

#model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained = True)
model_test = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
model_test.eval()

im = Image.open('20201112_072342.jpg').rotate(180)
# images = []
# images.append(im)

# transform = T.ToTensor()
# image_batch = transform(im).unsqueeze(0)
# #image_batch.shap

# val_dataloader = torch.utils.data.DataLoader(image_batch, batch_size=1, shuffle=True, num_workers=2)

# images = next(iter(val_dataloader))
# print(images.shape)
#print(targetmask.shape)
print(type(images))
#images = [ img.cuda() for img in images ]
transform = T.ToTensor()
image_batch = transform(im).unsqueeze(0)
# #image_batch.shap
print(image_batch)
predictions = model_test(image_batch)


print('Prediction keys:', predictions[0].keys())
print('Boxes shape:', predictions[0]['boxes'].shape)
print('Labels shape:', predictions[0]['labels'].shape)
print('Scores shape:', predictions[0]['scores'].shape)
print('Masks shape:', predictions[0]['masks'].shape)

import numpy as np
import cv2
import random

# Array of labels for COCO dataset (91 elements)

coco_names = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Random colors to use for labeling objects

COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3)).astype(np.uint8)

# Overlay masks, bounding boxes, and labels on input numpy image

def draw_segmentation_map(image, masks, boxes, labels):
    alpha = 1
    beta = 0.5 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # convert from RGB to OpenCV BGR format
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    for i in range(len(masks)):
        mask = masks[i,:,:]
        red_map = np.zeros_like(mask).astype(np.uint8)
        green_map = np.zeros_like(mask).astype(np.uint8)
        blue_map = np.zeros_like(mask).astype(np.uint8)
        # apply a randon color mask to each object
        color = COLORS[random.randrange(0, len(COLORS))]
        red_map[mask > 0.5] = color[0]
        green_map[mask > 0.5] = color[1]
        blue_map[mask > 0.5] = color[2]
        # combine all the masks into a single image
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
        # apply colored mask to the image
        image = cv2.addWeighted(image, alpha, segmentation_map, beta, gamma)
        # draw the bounding box around each object
        p1 = (int(boxes[i][0]), int(boxes[i][1]))
        p2 = (int(boxes[i][2]), int(boxes[i][3]))
        color = (int(color[0]), int(color[1]), int(color[2]))
        cv2.rectangle(image, p1, p2, color, 2)
        # put the label text above the objects
        p = (int(boxes[i][0]), int(boxes[i][1]-10))
        cv2.putText(image, labels[i], p, cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Overlay masks, bounding boxes, and labels of objects with scores greater than
# threshold on one of the images in the input tensor using the predictions output by Mask R-CNN.

def prediction_to_mask_image(images, predictions, img_index, threshold):
    scores = predictions[img_index]['scores']
    boxes_to_use = scores >= threshold
    img = (images[img_index].cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    masks = predictions[img_index]['masks'][boxes_to_use, :, :].cpu().detach().squeeze(1).numpy()
    boxes = predictions[img_index]['boxes'][boxes_to_use, :].cpu().detach().numpy()
    labels = predictions[img_index]['labels'][boxes_to_use].cpu().numpy()
    labels = [ coco_names[l] for l in labels ]

    return draw_segmentation_map(img, masks, boxes, labels)


from matplotlib import pyplot as plt

masked_img = prediction_to_mask_image(image_batch, predictions, 0, 0.5)
plt.figure(1, figsize=(12, 9), dpi=100)
plt.imshow(masked_img)
plt.title('Validation image result')
plt.show()
# Out:
# <class 'list'>
# tensor([[[[0.8314, 0.8314, 0.8353,  ..., 0.8275, 0.8275, 0.8314],
#           [0.8275, 0.8314, 0.8314,  ..., 0.8196, 0.8196, 0.8235],
#           [0.8314, 0.8353, 0.8353,  ..., 0.8314, 0.8235, 0.8235],
#           ...,
#           [0.3216, 0.3137, 0.2902,  ..., 0.1961, 0.1843, 0.1451],
#           [0.2902, 0.3098, 0.2745,  ..., 0.1255, 0.1098, 0.1255],
#           [0.2667, 0.2784, 0.2784,  ..., 0.1176, 0.1176, 0.2314]],
#
#          [[0.8510, 0.8510, 0.8549,  ..., 0.8471, 0.8471, 0.8510],
#           [0.8471, 0.8510, 0.8510,  ..., 0.8392, 0.8392, 0.8431],
#           [0.8510, 0.8549, 0.8549,  ..., 0.8510, 0.8431, 0.8431],
#           ...,
#           [0.3608, 0.3529, 0.3294,  ..., 0.2118, 0.2000, 0.1608],
#           [0.3294, 0.3490, 0.3137,  ..., 0.1412, 0.1255, 0.1412],
#           [0.3059, 0.3176, 0.3176,  ..., 0.1333, 0.1333, 0.2471]],
#
#          [[0.8745, 0.8745, 0.8784,  ..., 0.8706, 0.8706, 0.8745],
#           [0.8706, 0.8745, 0.8745,  ..., 0.8627, 0.8627, 0.8667],
#           [0.8745, 0.8784, 0.8784,  ..., 0.8745, 0.8667, 0.8667],
#           ...,
#           [0.3255, 0.3176, 0.2941,  ..., 0.2235, 0.2118, 0.1725],
#           [0.2941, 0.3137, 0.2784,  ..., 0.1529, 0.1373, 0.1529],
#           [0.2706, 0.2824, 0.2824,  ..., 0.1451, 0.1451, 0.2588]]]])
# Prediction keys: dict_keys(['boxes', 'labels', 'scores', 'masks'])
# Boxes shape: torch.Size([34, 4])
# Labels shape: torch.Size([34])
# Scores shape: torch.Size([34])
# Masks shape: torch.Size([34, 1, 3024, 4032])

# %% [markdown]
# # Pretrained Model Saved

# %%
# import copy
# import os

# import torch
# import torch.utils.data
# import torchvision
# import torchvision.transforms as T
# from pycocotools import mask as coco_mask
# from pycocotools.coco import COCO

# model_save = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
# print(model_save)
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
#   0%|          | 0.00/170M [00:04<?, ?B/s]

# %%
# import torch
# import torch.utils.data
# import torchvision
# model_save = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
# model_save.eval()
# Out:
# Could not connect to 127.0.0.1: 45145
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 462, in start_client
#     s.connect((host, port))
# ConnectionRefusedError: [Errno 111] Connection refused
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/google/colab/_debugpy.py", line 52, in attachment_entry
#     debugpy.listen(_dap_port)
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/__init__.py", line 113, in listen
#     return api.listen(address)
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/server/api.py", line 143, in debug
#     log.reraise_exception("{0}() failed:", func.__name__, level="info")
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/server/api.py", line 141, in debug
#     return func(address, settrace_kwargs, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/server/api.py", line 267, in listen
#     **settrace_kwargs
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/server/api.py", line 47, in _settrace
#     return pydevd.settrace(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/_vendored/pydevd/pydevd.py", line 2623, in settrace
#     notify_stdin=notify_stdin,
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/_vendored/pydevd/pydevd.py", line 2688, in _locked_settrace
#     py_db.connect(host, port)  # Note: connect can raise error.
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/_vendored/pydevd/pydevd.py", line 1262, in connect
#     s = start_client(host, port)
#   File "/usr/local/lib/python3.7/dist-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 462, in start_client
#     s.connect((host, port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
#   0%|          | 0.00/170M [00:01<?, ?B/s]
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 91, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
torch.save(model_save.state_dict(), ('finetune_results_weights_mask-rcnn.pth')
